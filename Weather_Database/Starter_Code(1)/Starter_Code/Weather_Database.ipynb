907235175, 25.899927391278453), (-17.936544623830926, -47.193058516221015), (-31.168965760694867, -86.982195269885), (25.191810961330347, 163.14160831172995), (-19.692480083902737, -32.117867637511324), (-59.57313046935179, -92.96585819241713), (60.60938525599238, 81.44830403692288), (34.74706961794149, 69.73587307312664), (-44.703315250102115, -123.78802996100816), (-65.03562272848026, 147.3349103902193), (-9.669448280010812, -95.04554078436657), (88.83266150364659, -145.90617246017288), (12.926062455761766, -92.32153621576492), (13.40256055899303, 162.5733333902087), (-57.85687241576858, -46.94917375289734), (65.92287317820742, -60.73045151332914), (77.10641380942991, -103.94682741047605), (28.770282540435574, 138.0263416500324), (65.23604733210954, -56.8511755340388), (-15.856637440038895, 80.62609803686775), (-40.245959093025846, 143.33527231570133), (-15.157397997000075, 92.65290560087874), (-35.55768562918352, 82.51755029496803), (-73.38856382947789, 143.28406840950908), (-87.15571821058157, -89.60308688237964), (-4.486300828850418, -127.14221031438191 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Assemble the OpenWeatherMap's API call
#city_url = url + "&q=" + city.replace(" ","+")

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Example of the JSON for Boston
#city_weather = requests.get(city_url)
#city_weather.json()

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
        
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #city_description = city_weather["weather"]["description"]      

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=naze
# Processing Record 1 of Set 1 | naze
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=fortuna
# Processing Record 2 of Set 1 | fortuna
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=khonuu
# Processing Record 3 of Set 1 | khonuu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=cabo+san+lucas
# Processing Record 4 of Set 1 | cabo san lucas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=ribeira+grande
# Processing Record 5 of Set 1 | ribeira grande
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=coquimbo
# Processing Record 6 of Set 1 | coquimbo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=hobart
# Processing Record 7 of Set 1 | hobart
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=kodiak
# Processing Record 8 of Set 1 | kodiak
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=albany
# Processing Record 9 of Set 1 | albany
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=bluff
# Processing Record 10 of Set 1 | bluff
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=pisco
# Processing Record 11 of Set 1 | pisco
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=luderitz
# Processing Record 12 of Set 1 | luderitz
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=bafq
# Processing Record 13 of Set 1 | bafq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=rikitea
# Processing Record 14 of Set 1 | rikitea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=camacha
# Processing Record 15 of Set 1 | camacha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=punta+arenas
# Processing Record 16 of Set 1 | punta arenas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=kaitangata
# Processing Record 17 of Set 1 | kaitangata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=malartic
# Processing Record 18 of Set 1 | malartic
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=bredasdorp
# Processing Record 19 of Set 1 | bredasdorp
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=torbay
# Processing Record 20 of Set 1 | torbay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=hambantota
# Processing Record 21 of Set 1 | hambantota
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=busselton
# Processing Record 22 of Set 1 | busselton
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=sobolevo
# Processing Record 23 of Set 1 | sobolevo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=ixtapa
# Processing Record 24 of Set 1 | ixtapa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=bonavista
# Processing Record 25 of Set 1 | bonavista
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=temaraia
# Processing Record 26 of Set 1 | temaraia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=belushya+guba
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=chokurdakh
# Processing Record 28 of Set 1 | chokurdakh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=ngukurr
# Processing Record 29 of Set 1 | ngukurr
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=kurilsk
# Processing Record 30 of Set 1 | kurilsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=illoqqortoormiut
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=provideniya
# Processing Record 32 of Set 1 | provideniya
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=laranjeiras+do+sul
# Processing Record 33 of Set 1 | laranjeiras do sul
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=taolanaro
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=hermanus
# Processing Record 35 of Set 1 | hermanus
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=port+alfred
# Processing Record 36 of Set 1 | port alfred
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=hearst
# Processing Record 37 of Set 1 | hearst
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=kuybysheve
# Processing Record 38 of Set 1 | kuybysheve
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=ibia
# Processing Record 39 of Set 1 | ibia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=lebu
# Processing Record 40 of Set 1 | lebu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=jamestown
# Processing Record 41 of Set 1 | jamestown
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=port+lincoln
# Processing Record 42 of Set 1 | port lincoln
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=puerto+ayora
# Processing Record 43 of Set 1 | puerto ayora
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=tuktoyaktuk
# Processing Record 44 of Set 1 | tuktoyaktuk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=gimli
# Processing Record 45 of Set 1 | gimli
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=jumla
# Processing Record 46 of Set 1 | jumla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=ayan
# Processing Record 47 of Set 1 | ayan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=nizhneyansk
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=kapaa
# Processing Record 49 of Set 1 | kapaa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eb21880dd51fd06f9f52bbcc7ea019&q=nikolskoye
# Processing Record 50 of Set 1 | nikolskoye
# City not found. Skipping...

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 0

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
